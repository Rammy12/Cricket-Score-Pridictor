# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
filenames=[]
for file in os.listdir('t20s_female'):
    filenames.append(os.path.join('t20s_female',file))

# %%
filenames[0:5]
# Out:
# ['t20s_female\\1043989.yaml',
#  't20s_female\\1043991.yaml',
#  't20s_female\\1043993.yaml',
#  't20s_female\\1044211.yaml',
#  't20s_female\\1050615.yaml']

# %%
final_df=pd.DataFrame()
count=1
for file in tqdm(filenames):
    with open(file,'r') as f:
        df=pd.json_normalize(safe_load(f))
        df['match_id']=count
        final_df=pd.concat([final_df,df])
        count+=1
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████▉| 861/862 [07:09<00:00,  2.00it/s]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [6], in <cell line: 3>()
#       3 for file in tqdm(filenames):
#       4     with open(file,'r') as f:
# ----> 5         df=pd.json_normalize(safe_load(f))
#       6         df['match_id']=count
#       7         final_df=pd.concat([final_df,df])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\json\_normalize.py:443, in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     441     data = list(data)
#     442 else:
# --> 443     raise NotImplementedError
#     445 # check to see if a simple recursive function is possible to
#     446 # improve performance (see #15621) but only for cases such
#     447 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     448 if (
#     449     record_path is None
#     450     and meta is None
#    (...)
#     453     and max_level is None
#     454 ):
#
# NotImplementedError:

# %%
final_df
# Out:
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...               0.91
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...               0.91
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...               0.91
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
# 0   [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 0   [{'1st innings': {'team': 'West Indies', 'deli...               0.91
# 0   [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.dates info.gender  \
# 0    2017-02-17              1                  6.0  [2017-02-17]      female
# 0    2017-02-19              1                  6.0  [2017-02-19]      female
# 0    2017-02-23              1                  6.0  [2017-02-22]      female
# 0    2016-09-30              1                  6.0  [2016-09-27]      female
# 0    2016-11-22              1                  6.0  [2016-11-21]      female
# ..          ...            ...                  ...           ...         ...
# 0    2016-03-28              2                  6.0  [2016-03-28]      female
# 0    2016-03-30              2                  6.0  [2016-03-30]      female
# 0    2016-03-31              2                  6.0  [2016-03-31]      female
# 0    2016-04-03              2                  6.0  [2016-04-03]      female
# 0    2016-09-12              1                  6.0  [2016-09-05]      female
#
#    info.match_type  info.outcome.by.runs info.outcome.winner  ...  \
# 0              T20                  40.0           Australia  ...
# 0              T20                   8.0         New Zealand  ...
# 0              T20                  47.0         New Zealand  ...
# 0              T20                   NaN           Australia  ...
# 0              T20                  14.0         New Zealand  ...
# ..             ...                   ...                 ...  ...
# 0              T20                  10.0           Sri Lanka  ...
# 0              T20                   5.0           Australia  ...
# 0              T20                   6.0         West Indies  ...
# 0              T20                   NaN         West Indies  ...
# 0              T20                   6.0             Ireland  ...
#
#     info.registry.people.O Kirsten  \
# 0                              NaN
# 0                              NaN
# 0                              NaN
# 0                              NaN
# 0                              NaN
# ..                             ...
# 0                              NaN
# 0                              NaN
# 0                              NaN
# 0                              NaN
# 0                              NaN
#
#    info.registry.people.Mohammad Rashid Ali Khan  \
# 0                                            NaN
# 0                                            NaN
# 0                                            NaN
# 0                                            NaN
# 0                                            NaN
# ..                                           ...
# 0                                            NaN
# 0                                            NaN
# 0                                            NaN
# 0                                            NaN
# 0                                            NaN
#
#    info.registry.people.Riazuddin info.registry.people.JD Cloete  \
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# ..                            ...                            ...
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
#
#    info.registry.people.C Shamshuddin info.registry.people.AK Chaudhary  \
# 0                                 NaN                               NaN
# 0                                 NaN                               NaN
# 0                                 NaN                               NaN
# 0                                 NaN                               NaN
# 0                                 NaN                               NaN
# ..                                ...                               ...
# 0                                 NaN                               NaN
# 0                                 NaN                               NaN
# 0                                 NaN                               NaN
# 0                                 NaN                               NaN
# 0                                 NaN                               NaN
#
#    info.registry.people.Navdeep Singh info.registry.people.VA Kulkarni  \
# 0                                 NaN                              NaN
# 0                                 NaN                              NaN
# 0                                 NaN                              NaN
# 0                                 NaN                              NaN
# 0                                 NaN                              NaN
# ..                                ...                              ...
# 0                                 NaN                         8fe0c4f8
# 0                                 NaN                              NaN
# 0                                 NaN                              NaN
# 0                                 NaN                              NaN
# 0                                 NaN                              NaN
#
#    info.registry.people.Ranjeev Sharma info.registry.people.VK Sharma
# 0                                  NaN                            NaN
# 0                                  NaN                            NaN
# 0                                  NaN                            NaN
# 0                                  NaN                            NaN
# 0                                  NaN                            NaN
# ..                                 ...                            ...
# 0                                  NaN                            NaN
# 0                                  NaN                            NaN
# 0                                  NaN                            NaN
# 0                                  NaN                            NaN
# 0                                  NaN                            NaN
#
# [861 rows x 1933 columns]

# %%
data=final_df[['innings','info.dates','info.match_type','info.gender','info.outcome.winner','info.overs','info.player_of_match','info.teams',
             'info.toss.decision','info.toss.winner','info.umpires','info.venue','match_id','info.city','info.outcome.by.wickets']]

# %%
data
# Out:
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...  [2017-02-19]
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-27]
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...  [2016-11-21]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-28]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2016-03-30]
# 0   [{'1st innings': {'team': 'West Indies', 'deli...  [2016-03-31]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2016-04-03]
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...  [2016-09-05]
#
#    info.match_type info.gender info.outcome.winner  info.overs  \
# 0              T20      female           Australia          20
# 0              T20      female         New Zealand          20
# 0              T20      female         New Zealand          20
# 0              T20      female           Australia          20
# 0              T20      female         New Zealand          20
# ..             ...         ...                 ...         ...
# 0              T20      female           Sri Lanka          20
# 0              T20      female           Australia          20
# 0              T20      female         West Indies          20
# 0              T20      female         West Indies          20
# 0              T20      female             Ireland          20
#
#    info.player_of_match                  info.teams info.toss.decision  \
# 0          [EJ Villani]    [Australia, New Zealand]              field
# 0         [AM Peterson]    [Australia, New Zealand]              field
# 0            [SW Bates]    [Australia, New Zealand]                bat
# 0            [KM Beams]      [Sri Lanka, Australia]              field
# 0                   NaN     [New Zealand, Pakistan]                bat
# ..                  ...                         ...                ...
# 0        [AC Jayangani]   [South Africa, Sri Lanka]                bat
# 0          [MM Lanning]        [Australia, England]              field
# 0            [B Cooper]  [New Zealand, West Indies]              field
# 0         [HK Matthews]    [Australia, West Indies]                bat
# 0                   NaN       [Ireland, Bangladesh]              field
#
#    info.toss.winner                   info.umpires  \
# 0       New Zealand          [GA Abood, SAJ Craig]
# 0         Australia           [SAJ Craig, JD Ward]
# 0       New Zealand            [GA Abood, JD Ward]
# 0         Australia  [JWHD Boteju, ID Gunawardene]
# 0       New Zealand            [K Cross, D Venter]
# ..              ...                            ...
# 0         Sri Lanka            [SD Fry, JS Wilson]
# 0           England          [CB Gaffaney, S Ravi]
# 0       New Zealand     [RK Illingworth, NJ Llong]
# 0         Australia    [Aleem Dar, RK Illingworth]
# 0        Bangladesh            [R Black, AJ Neill]
#
#                            info.venue  match_id    info.city  \
# 0            Melbourne Cricket Ground         1          NaN
# 0      Simonds Stadium, South Geelong         2     Victoria
# 0                       Adelaide Oval         3          NaN
# 0        Sinhalese Sports Club Ground         4      Colombo
# 0                         Saxton Oval         5       Nelson
# ..                                ...       ...          ...
# 0               M Chinnaswamy Stadium       857    Bangalore
# 0                    Feroz Shah Kotla       858        Delhi
# 0                    Wankhede Stadium       859       Mumbai
# 0                        Eden Gardens       860      Kolkata
# 0   Bready Cricket Club, Magheramason       861  Londonderry
#
#     info.outcome.by.wickets
# 0                       NaN
# 0                       NaN
# 0                       NaN
# 0                      10.0
# 0                       NaN
# ..                      ...
# 0                       NaN
# 0                       NaN
# 0                       NaN
# 0                       8.0
# 0                       NaN
#
# [861 rows x 15 columns]

# %%
data['info.gender'].value_counts()
# Out:
# female    861
# Name: info.gender, dtype: int64

# %%
data['info.match_type'].value_counts()
# Out:
# T20    861
# Name: info.match_type, dtype: int64

# %%
data['info.overs'].value_counts()
# Out:
# 20    857
# 50      4
# Name: info.overs, dtype: int64

# %%
data=data[data['info.overs']==20]
data.drop(columns=['info.overs','info.match_type'],inplace=True)
# Out:
# C:\Users\91776\AppData\Local\Temp\ipykernel_25712\697669965.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=['info.overs','info.match_type'],inplace=True)
